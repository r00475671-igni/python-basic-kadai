# %% [markdown]
# 以下のコードを実行するとスコープに関するエラーが発生します。
#
# エラーを修正して正しく計算結果が出力されるようにしてください。
#
#
#
# price1 = 100
# price2 = 200
#
# def total():
#     tax = 1.1
#     return price1 + price2
#
# print (total() * tax)

# %%
tax = 1.1

def total():

    price1 = 100
    price2 = 200
    return price1 + price2

print (total() * tax)
# Out:
# 330.0
